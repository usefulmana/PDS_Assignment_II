# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
warnings.filterwarnings('ignore')
data_location = 'data/wine.csv'
plt.style.use('seaborn')
df = pd.read_csv(filepath_or_buffer=data_location, sep=',', decimal='.', header=None, names=[
    'Label', 'Alcohol', 'Malic Acid', 'Ash', 'Alkalinity of ash', 'Magnesium', 'Total phenols', 'Flavanoids' , 
    'Nonflavanoid phenols', 'Proanthocyanins', 'Color intensity', 'Hue', 'OD280/OD315 of diluted wines', 'Proline']
)
df.head(10)
# Out:
#    Label  Alcohol  Malic Acid   Ash  Alkalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
# 5      1    14.20        1.76  2.45               15.2        112
# 6      1    14.39        1.87  2.45               14.6         96
# 7      1    14.06        2.15  2.61               17.6        121
# 8      1    14.83        1.64  2.17               14.0         97
# 9      1    13.86        1.35  2.27               16.0         98
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
# 5           3.27        3.39                  0.34             1.97
# 6           2.50        2.52                  0.30             1.98
# 7           2.60        2.51                  0.31             1.25
# 8           2.80        2.98                  0.29             1.98
# 9           2.98        3.15                  0.22             1.85
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             5.64  1.04                          3.92     1065
# 1             4.38  1.05                          3.40     1050
# 2             5.68  1.03                          3.17     1185
# 3             7.80  0.86                          3.45     1480
# 4             4.32  1.04                          2.93      735
# 5             6.75  1.05                          2.85     1450
# 6             5.25  1.02                          3.58     1290
# 7             5.05  1.06                          3.58     1295
# 8             5.20  1.08                          2.85     1045
# 9             7.22  1.01                          3.55     1045

# %%
# Graph for Labels
val = df['Label'].value_counts()
val.plot(kind='pie', autopct=lambda p: '{:.0f}% ({:.0f})'.format(p, p * sum(val)/100), fontsize=12)
plt.axis("equal")
plt.title('Label Distribution')
plt.legend(loc='best')
plt.savefig('single/label.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for alcohol %
sns.boxplot(x='Alcohol', data=df, orient='v', width=0.2)
plt.title('Alcoholic Content Statistics')
plt.legend()
plt.grid()
plt.ylabel('Alcoholic Content')
plt.savefig('single/alcohol.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for alcohol %
sns.kdeplot(data=df['Malic Acid'])
plt.title('Malic Acid Distribution')
plt.legend()
plt.grid()
plt.xlabel('Malic Acid Content')
plt.ylabel('Density Function')
plt.savefig('single/malic_acid.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for ash %
df['Ash'].plot(kind='hist', bins=10, edgecolor="k", facecolor='blue')
plt.title('Ash Content Statistics')
plt.legend()
plt.xlabel('Ash Content')
plt.ylabel('Frequency')
plt.savefig('single/ash.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for magnesium %
df['Magnesium'].plot(kind='hist', bins=10, edgecolor="k", facecolor='orange')
plt.title('Magnesium Content Statistics')
plt.legend()
plt.xlabel('Magnesium Content')
plt.ylabel('Frequency')
plt.savefig('single/magnesium.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for Flavanoids %
sns.boxplot(x='Flavanoids', data=df, orient='v', width=0.2)
plt.title('Flavanoids Content Statistics')
plt.legend()
plt.grid()
plt.ylabel('Flavanoids Content')
plt.savefig('single/flavanoids.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for Proline
df['Proline'].plot(kind='hist', bins=10, edgecolor="k", facecolor='teal')
plt.title('Proline Content Distribution')
plt.legend()
plt.xlabel('Proline Content')
plt.savefig('single/proline.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for phenols
sns.distplot(df['Total phenols'], bins=10, color='green')
plt.title('Phenols Distribution')
plt.legend()
plt.grid()
plt.xlabel('Phenols Acid Content')
plt.ylabel('Density Function')
plt.savefig('single/phenols.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for Proanthocyanins
sns.boxplot(x='Proanthocyanins', data=df, orient='v', width=0.2)
plt.title('Proanthocyanins Content Statistics')
plt.legend()
plt.grid()
plt.ylabel('Proanthocyanins Content')
plt.savefig('single/proanthocyanins.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
df['Color intensity'].plot(kind='hist', bins=10, edgecolor="k", facecolor='red')
plt.title('Color intensity Distribution')
plt.legend()
plt.xlabel('Color Intensity')
plt.savefig('single/color_intensity.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
sns.boxplot(x='Label', y='Alcohol', data=df, width=0.3)
plt.suptitle(' ')
plt.ylabel('Alcohol Content')
plt.title('Alcohol Content by Label')
plt.savefig('pair/label_alcohol.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
sns.boxplot(x='Label', y='Malic Acid', data=df, width=0.3)
plt.suptitle(' ')
plt.ylabel('Malic Acid Content')
plt.title('Malic Acid Content by Label')
plt.savefig('pair/label_malic-acid.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
df.groupby('Label')['Color intensity'].plot(kind='density')
plt.xlabel('Color Intensity')
plt.ylabel('Density')
plt.title('Color Intensity by Label')
plt.legend()
plt.savefig('pair/label_cintensity.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
ax = df.groupby('Label')['Ash'].mean().plot.barh(color=['blue', 'orange', 'green'])
ax.set_xlim(0,4)
plt.ylabel('Label')
plt.xlabel('Ash Content')
plt.title('Average Ash Content by Label')
plt.savefig('pair/label_ash.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for hue-color_intensity
sns.lmplot(x = 'Color intensity', y='Hue', data=df)
plt.title('Hue & Color Intensity')
plt.savefig('pair/hue-color_intensity.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for ash-acalinity
sns.lmplot(x = 'Alkalinity of ash', y='Ash', data=df)
plt.title('Ash and its Alkalinity')
plt.savefig('pair/ash_alcalinity.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for hue-Proanthocyanins
sns.lmplot(x = 'Proanthocyanins', y='Hue', data=df)
plt.title('Proanthocyanins and Hue')
plt.savefig('pair/hue_proanthocyanins.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for total phenols-flavanoids
sns.lmplot(x = 'Total phenols', y='Flavanoids', data=df)
plt.title('Total Phenols & Flavanoids')
plt.savefig('pair/flavanoid_phenols.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for total phenols-flavanoids
sns.lmplot(x = 'Color intensity', y='Alcohol', data=df)
plt.title('Alcohol & Color Intensity')
plt.savefig('pair/alcohol_cintensity.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for label-hue
plt.figure(figsize=(10,6))
sns.violinplot(x='Label', y='Hue', data=df, inner=None)
sns.swarmplot(x='Label', y='Hue', data=df, color='k', alpha=0.5)
plt.title('Hue Distribution by Label')
plt.savefig('pair/label_hue.png', bbox_inches='tight')
plt.show()
plt.close()

# %%
# Classification Tasks
# Decision Tree and k Nearest Neighbors
# Preparing Data Set
data = df.copy()
features = ['Alcohol', 'Malic Acid', 'Ash', 'Alkalinity of ash', 'Magnesium', 'Total phenols', 'Flavanoids' , 
    'Nonflavanoid phenols', 'Proanthocyanins', 'Color intensity', 'Hue', 'OD280/OD315 of diluted wines', 'Proline']
Y = data[['Label']].copy()
X = data[features].copy()

# %%
def array_split(a, n):
    k, m = divmod(len(a), n)
    return (a[i * k + min(i, m):(i + 1) * k + min(i + 1, m)] for i in xrange(n))

# %%
def draw_line_plots(x_axis,x_axis_name, array, test_size, filename):
    length = len(x_axis)
    # Split the array into x_axis sized chunks
    split_array = list(array_split(array, len(x_axis)))
    pan = pd.Panel(split_array)
    # Convert the 3D array into a Dataframe
    scores = pan.swapaxes(0, 2).to_frame()
    # Naming the columns 
    scores.columns = ['Error Rate', 'Recall Score', 'F1 Score', 'Precision Score']
    # Plotting 
    for i in range(len(test_size)):
        sns.lineplot(x=x_axis, y=scores['Error Rate'][(length*i):(length+length*i)],marker="s", label='Error Rate')
        sns.lineplot(x=x_axis, y=scores['Recall Score'][(length*i):(length+length*i)], marker="s", label='Recall Score')
        sns.lineplot(x=x_axis, y=scores['F1 Score'][(length*i):(length+length*i)], marker="s", label='F1 Score')
        sns.lineplot(x=x_axis, y=scores['Precision Score'][(length*i):(length+length*i)], marker="s", label='Precision Score')
        plt.ylim(-0.1,1.1)
        plt.title('{:.0f}%'.format(test_size[i]*100))
        plt.ylabel(' ')
        plt.xlabel(x_axis_name)
        plt.legend(loc='best')
        plt.savefig('modelling/{}_{:.0f}.png'.format(filename, test_size[i]*100, bbox_inches='tight'))
        plt.show()
        plt.close()

# %%
def train_model_with_decision_tree(max_leaf_nodes, random_state, test_size, x, y, max_features=None):
    X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = test_size, random_state = 20)
    dt = DecisionTreeClassifier(max_leaf_nodes = max_leaf_nodes, random_state = random_state, max_features=max_features)
    dt = dt.fit(X_train, Y_train)
    # Test
    dt_predictions = dt.predict(X_test)
    con_matrix = confusion_matrix(y_true = Y_test, y_pred = dt_predictions)
    error_rate = 1 - accuracy_score(y_true = Y_test, y_pred = dt_predictions)
    re_score = recall_score(y_true = Y_test, y_pred = dt_predictions, average='weighted')
    f_score = f1_score(y_true = Y_test, y_pred = dt_predictions, average='weighted')
    p_score = precision_score(y_true = Y_test, y_pred = dt_predictions, average='weighted')
    # Confusion Matrix
    print ('Confusion Matrix:')
    print con_matrix
    # Accuracy score
    print 'Error Rate: ' + str(error_rate)
    # Recall Score
    print 'Recall Score: ' + str(re_score)
    # F1 Score
    print 'F1 Score: ' +  str(f_score)
    # Precision Score
    print 'Precision Score: ' + str(p_score)
    return [error_rate, re_score, f_score, p_score]

# %%
def mass_dt_trainer(max_features=[i for i in range(1,13)], test_size=[0.2, 0.4, 0.5], max_leaf_nodes=15, random_state=20, x=X, y=Y):
    score_list = []
    for i in max_features:
        for j in test_size:
            print ('Performance results for max_features = {}, test_size = {}'.format(i, j))
            score_list.append(train_model_with_decision_tree(max_leaf_nodes=15, random_state=20, test_size=j, x=X, y=Y, max_features=i))
            print('')
    draw_line_plots(max_features,'Max Features', score_list, test_size, 'dt')

# %%
mass_dt_trainer()
# Out:
# Performance results for max_features = 1, test_size = 20.0%
# Confusion Matrix:
# [[ 9  0  1]
#  [ 0 14  3]
#  [ 0  0  9]]
# Error Rate: 0.11111111111111116
# Recall Score: 0.8888888888888888
# F1 Score: 0.8942266467733361
# Precision Score: 0.9230769230769231
#
# Performance results for max_features = 1, test_size = 40.0%
# Confusion Matrix:
# [[18  2  1]
#  [ 0 28  6]
#  [ 0  0 17]]
# Error Rate: 0.125
# Recall Score: 0.875
# F1 Score: 0.8782246716697936
# Precision Score: 0.8996527777777779
#
# Performance results for max_features = 1, test_size = 50.0%
# Confusion Matrix:
# [[25  3  1]
#  [ 0 36  5]
#  [ 0  2 17]]
# Error Rate: 0.1235955056179775
# Recall Score: 0.8764044943820225
# F1 Score: 0.8790202722786992
# Precision Score: 0.8881289692232535
#
# Performance results for max_features = 2, test_size = 20.0%
# Confusion Matrix:
# [[10  0  0]
#  [ 1 15  1]
#  [ 0  0  9]]
# Error Rate: 0.05555555555555558
# Recall Score: 0.9444444444444444
# F1 Score: 0.9441007031467559
# Precision Score: 0.9497474747474747
#
# Performance results for max_features = 2, test_size = 40.0%
# Confusion Matrix:
# [[21  0  0]
#  [ 1 32  1]
#  [ 0  1 16]]
# Error Rate: 0.04166666666666663
# Recall Score: 0.9583333333333334
# F1 Score: 0.9581838867677119
# Precision Score: 0.9585437710437711
#
# Performance results for max_features = 2, test_size = 50.0%
# Confusion Matrix:
# [[29  0  0]
#  [ 1 39  1]
#  [ 0  1 18]]
# Error Rate: 0.0337078651685393
# Recall Score: 0.9662921348314607
# F1 Score: 0.9661792815477828
# Precision Score: 0.9663857677902622
#
# Performance results for max_features = 3, test_size = 20.0%
# Confusion Matrix:
# [[ 9  1  0]
#  [ 2 14  1]
#  [ 0  0  9]]
# Error Rate: 0.11111111111111116
# Recall Score: 0.8888888888888888
# F1 Score: 0.8881317878028404
# Precision Score: 0.893013468013468
#
# Performance results for max_features = 3, test_size = 40.0%
# Confusion Matrix:
# [[19  2  0]
#  [ 3 31  0]
#  [ 0  2 15]]
# Error Rate: 0.09722222222222221
# Recall Score: 0.9027777777777778
# F1 Score: 0.9034217246189566
# Precision Score: 0.9062590187590188
#
# Performance results for max_features = 3, test_size = 50.0%
# Confusion Matrix:
# [[28  1  0]
#  [ 3 38  0]
#  [ 0  2 17]]
# Error Rate: 0.0674157303370787
# Recall Score: 0.9325842696629213
# F1 Score: 0.9327091136079899
# Precision Score: 0.9347589706415367
#
# Performance results for max_features = 4, test_size = 20.0%
# Confusion Matrix:
# [[10  0  0]
#  [ 1 16  0]
#  [ 0  1  8]]
# Error Rate: 0.05555555555555558
# Recall Score: 0.9444444444444444
# F1 Score: 0.9442888266417678
# Precision Score: 0.946969696969697
#
# Performance results for max_features = 4, test_size = 40.0%
# Confusion Matrix:
# [[21  0  0]
#  [ 1 33  0]
#  [ 0  2 15]]
# Error Rate: 0.04166666666666663
# Recall Score: 0.9583333333333334
# F1 Score: 0.9579287088529378
# Precision Score: 0.9597582972582974
#
# Performance results for max_features = 4, test_size = 50.0%
# Confusion Matrix:
# [[29  0  0]
#  [ 4 37  0]
#  [ 0  2 17]]
# Error Rate: 0.0674157303370787
# Recall Score: 0.9325842696629213
# F1 Score: 0.9325671539607747
# Precision Score: 0.9368795998009481
#
# Performance results for max_features = 5, test_size = 20.0%
# Confusion Matrix:
# [[10  0  0]
#  [ 0 17  0]
#  [ 0  0  9]]
# Error Rate: 0.0
# Recall Score: 1.0
# F1 Score: 1.0
# Precision Score: 1.0
#
# Performance results for max_features = 5, test_size = 40.0%
# Confusion Matrix:
# [[21  0  0]
#  [ 1 31  2]
#  [ 0  2 15]]
# Error Rate: 0.06944444444444442
# Recall Score: 0.9305555555555556
# F1 Score: 0.9301988121408462
# Precision Score: 0.9303451178451179
#
# Performance results for max_features = 5, test_size = 50.0%
# Confusion Matrix:
# [[28  0  1]
#  [ 1 37  3]
#  [ 0  2 17]]
# Error Rate: 0.0786516853932584
# Recall Score: 0.9213483146067416
# F1 Score: 0.922191011235955
# Precision Score: 0.9244762727908795
#
# Performance results for max_features = 6, test_size = 20.0%
# Confusion Matrix:
# [[ 9  1  0]
#  [ 0 16  1]
#  [ 0  0  9]]
# Error Rate: 0.05555555555555558
# Recall Score: 0.9444444444444444
# F1 Score: 0.9444444444444444
# Precision Score: 0.9472222222222223
#
# Performance results for max_features = 6, test_size = 40.0%
# Confusion Matrix:
# [[18  3  0]
#  [ 1 32  1]
#  [ 0  0 17]]
# Error Rate: 0.06944444444444442
# Recall Score: 0.9305555555555556
# F1 Score: 0.9298682999769956
# Precision Score: 0.9310556483802098
#
# Performance results for max_features = 6, test_size = 50.0%
# Confusion Matrix:
# [[27  2  0]
#  [ 1 39  1]
#  [ 0  0 19]]
# Error Rate: 0.0449438202247191
# Recall Score: 0.9550561797752809
# F1 Score: 0.9549045474533351
# Precision Score: 0.9552166934189407
#
# Performance results for max_features = 7, test_size = 20.0%
# Confusion Matrix:
# [[10  0  0]
#  [ 0 16  1]
#  [ 0  0  9]]
# Error Rate: 0.02777777777777779
# Recall Score: 0.9722222222222222
# F1 Score: 0.9725323409533936
# Precision Score: 0.9750000000000001
#
# Performance results for max_features = 7, test_size = 40.0%
# Confusion Matrix:
# [[21  0  0]
#  [ 0 33  1]
#  [ 0  0 17]]
# Error Rate: 0.01388888888888884
# Recall Score: 0.9861111111111112
# F1 Score: 0.98620587538498
# Precision Score: 0.9868827160493827
#
# Performance results for max_features = 7, test_size = 50.0%
# Confusion Matrix:
# [[29  0  0]
#  [ 0 40  1]
#  [ 0  0 19]]
# Error Rate: 0.011235955056179803
# Recall Score: 0.9887640449438202
# F1 Score: 0.9888387379024083
# Precision Score: 0.9893258426966292
#
# Performance results for max_features = 8, test_size = 20.0%
# Confusion Matrix:
# [[10  0  0]
#  [ 2 14  1]
#  [ 0  0  9]]
# Error Rate: 0.08333333333333337
# Recall Score: 0.9166666666666666
# F1 Score: 0.9158906552794499
# Precision Score: 0.9287037037037038
#
# Performance results for max_features = 8, test_size = 40.0%
# Confusion Matrix:
# [[19  2  0]
#  [ 1 32  1]
#  [ 0  0 17]]
# Error Rate: 0.05555555555555558
# Recall Score: 0.9444444444444444
# F1 Score: 0.9441347270615563
# Precision Score: 0.9445216049382716
#
# Performance results for max_features = 8, test_size = 50.0%
# Confusion Matrix:
# [[23  1  5]
#  [ 2 38  1]
#  [ 2  6 11]]
# Error Rate: 0.1910112359550562
# Recall Score: 0.8089887640449438
# F1 Score: 0.8052258182255569
# Precision Score: 0.8047195907076937
#
# Performance results for max_features = 9, test_size = 20.0%
# Confusion Matrix:
# [[ 9  1  0]
#  [ 0 17  0]
#  [ 0  0  9]]
# Error Rate: 0.02777777777777779
# Recall Score: 0.9722222222222222
# F1 Score: 0.9718880534670008
# Precision Score: 0.9737654320987654
#
# Performance results for max_features = 9, test_size = 40.0%
# Confusion Matrix:
# [[19  2  0]
#  [ 0 33  1]
#  [ 0  0 17]]
# Error Rate: 0.04166666666666663
# Recall Score: 0.9583333333333334
# F1 Score: 0.9581392339544514
# Precision Score: 0.9598985890652556
#
# Performance results for max_features = 9, test_size = 50.0%
# Confusion Matrix:
# [[28  1  0]
#  [ 0 41  0]
#  [ 0  1 18]]
# Error Rate: 0.022471910112359605
# Recall Score: 0.9775280898876404
# F1 Score: 0.9775452143873197
# Precision Score: 0.9785732950091456
#
# Performance results for max_features = 10, test_size = 20.0%
# Confusion Matrix:
# [[10  0  0]
#  [ 2 15  0]
#  [ 0  1  8]]
# Error Rate: 0.08333333333333337
# Recall Score: 0.9166666666666666
# F1 Score: 0.9171122994652406
# Precision Score: 0.9241898148148149
#
# Performance results for max_features = 10, test_size = 40.0%
# Confusion Matrix:
# [[21  0  0]
#  [ 2 32  0]
#  [ 0  1 16]]
# Error Rate: 0.04166666666666663
# Recall Score: 0.9583333333333334
# F1 Score: 0.9584432634805768
# Precision Score: 0.9603279168496558
#
# Performance results for max_features = 10, test_size = 50.0%
# Confusion Matrix:
# [[29  0  0]
#  [ 1 40  0]
#  [ 0  1 18]]
# Error Rate: 0.022471910112359605
# Recall Score: 0.9775280898876404
# F1 Score: 0.9774714726152547
# Precision Score: 0.9779026217228464
#
# Performance results for max_features = 11, test_size = 20.0%
# Confusion Matrix:
# [[ 9  1  0]
#  [ 0 17  0]
#  [ 0  1  8]]
# Error Rate: 0.05555555555555558
# Recall Score: 0.9444444444444444
# F1 Score: 0.9444396667048885
# Precision Score: 0.9502923976608186
#
# Performance results for max_features = 11, test_size = 40.0%
# Confusion Matrix:
# [[19  2  0]
#  [ 3 31  0]
#  [ 0  1 16]]
# Error Rate: 0.08333333333333337
# Recall Score: 0.9166666666666666
# F1 Score: 0.9172637224962806
# Precision Score: 0.9185606060606061
#
# Performance results for max_features = 11, test_size = 50.0%
# Confusion Matrix:
# [[27  2  0]
#  [ 2 39  0]
#  [ 0  0 19]]
# Error Rate: 0.0449438202247191
# Recall Score: 0.9550561797752809
# F1 Score: 0.9550561797752809
# Precision Score: 0.9550561797752809
#
# Performance results for max_features = 12, test_size = 20.0%
# Confusion Matrix:
# [[10  0  0]
#  [ 0 16  1]
#  [ 0  0  9]]
# Error Rate: 0.02777777777777779
# Recall Score: 0.9722222222222222
# F1 Score: 0.9725323409533936
# Precision Score: 0.9750000000000001
#
# Performance results for max_features = 12, test_size = 40.0%
# Confusion Matrix:
# [[20  1  0]
#  [ 1 33  0]
#  [ 0  0 17]]
# Error Rate: 0.02777777777777779
# Recall Score: 0.9722222222222222
# F1 Score: 0.9722222222222222
# Precision Score: 0.9722222222222222
#
# Performance results for max_features = 12, test_size = 50.0%
# Confusion Matrix:
# [[28  1  0]
#  [ 1 40  0]
#  [ 0  0 19]]
# Error Rate: 0.022471910112359605
# Recall Score: 0.9775280898876404
# F1 Score: 0.9775280898876404
# Precision Score: 0.9775280898876404

# %%
def train_model_with_kNN(k_number, test_size, x,y, weights='uniform', random_state=20):
    kN = KNeighborsClassifier(k_number, weights)
    X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = test_size, random_state = random_state)
    kN.fit(X_train, Y_train.values.ravel())
    kN_predictions = kN.predict(X_test)
    con_matrix = confusion_matrix(y_true = Y_test, y_pred = kN_predictions)
    error_rate = 1 - accuracy_score(y_true = Y_test, y_pred = kN_predictions)
    re_score = recall_score(y_true = Y_test, y_pred = kN_predictions, average='weighted')
    f_score = f1_score(y_true = Y_test, y_pred = kN_predictions, average='weighted')
    p_score = precision_score(y_true = Y_test, y_pred = kN_predictions, average='weighted')
    # Confusion Matrix
    print 'Confusion Maxtrix: '
    print con_matrix
    # Accuracy score
    print 'Error Rate: ' + str(error_rate)
    # Recall Score
    print 'Recall Score: ' + str(re_score)
    # F1 Score
    print 'F1 Score: ' +  str(f_score)
    # Precision Score
    print 'Precision Score: ' + str(p_score)
    
    return [error_rate, re_score, f_score, p_score]

# %%
def mass_kNN_trainer(k=[i for i in range(1,11)], test_size=[0.2, 0.4, 0.5], weights='uniform', random_state=20, x=X, y=Y):
    score_list = []
    for i in k:
        for j in test_size:
            print ('Performance results for k = {}, test_size = {}, weights = {}'.format(i, j, weights))
            score_list.append(train_model_with_kNN(k_number=i, test_size=j, x=x,y=y, weights=weights, 
                                                    random_state=random_state))
            print('')
    draw_line_plots(k,'k', score_list, test_size, 'kNN_{}'.format(weights))

# %%
# Uniform Trainer
mass_kNN_trainer()
# Out:
# Performance results for k = 1, test_size = 20.0%, weights = uniform
# Confusion Maxtrix:
# [[10  0  0]
#  [ 0 11  6]
#  [ 0  4  5]]
# Error Rate: 0.2777777777777778
# Recall Score: 0.7222222222222222
# F1 Score: 0.7274305555555556
# Precision Score: 0.7377104377104376
#
# Performance results for k = 1, test_size = 40.0%, weights = uniform
# Confusion Maxtrix:
# [[18  2  1]
#  [ 0 23 11]
#  [ 2  7  8]]
# Error Rate: 0.3194444444444444
# Recall Score: 0.6805555555555556
# F1 Score: 0.687324242202291
# Precision Score: 0.6963541666666667
#
# Performance results for k = 1, test_size = 50.0%, weights = uniform
# Confusion Maxtrix:
# [[27  1  1]
#  [ 1 26 14]
#  [ 2  8  9]]
# Error Rate: 0.3033707865168539
# Recall Score: 0.6966292134831461
# F1 Score: 0.702792054296588
# Precision Score: 0.7155296950240772
#
# Performance results for k = 2, test_size = 20.0%, weights = uniform
# Confusion Maxtrix:
# [[10  0  0]
#  [ 0 12  5]
#  [ 1  6  2]]
# Error Rate: 0.33333333333333337
# Recall Score: 0.6666666666666666
# F1 Score: 0.6508597883597883
# Precision Score: 0.6387686387686387
#
# Performance results for k = 2, test_size = 40.0%, weights = uniform
# Confusion Maxtrix:
# [[19  1  1]
#  [ 3 23  8]
#  [ 3  9  5]]
# Error Rate: 0.3472222222222222
# Recall Score: 0.6527777777777778
# F1 Score: 0.6413191755109446
# Precision Score: 0.6351166426166426
#
# Performance results for k = 2, test_size = 50.0%, weights = uniform
# Confusion Maxtrix:
# [[27  1  1]
#  [ 5 25 11]
#  [ 4  9  6]]
# Error Rate: 0.348314606741573
# Recall Score: 0.651685393258427
# F1 Score: 0.6430129670224288
# Precision Score: 0.6445960406634564
#
# Performance results for k = 3, test_size = 20.0%, weights = uniform
# Confusion Maxtrix:
# [[10  0  0]
#  [ 0 10  7]
#  [ 1  3  5]]
# Error Rate: 0.3055555555555556
# Recall Score: 0.6944444444444444
# F1 Score: 0.6984126984126984
# Precision Score: 0.7199397824397824
#
# Performance results for k = 3, test_size = 40.0%, weights = uniform
# Confusion Maxtrix:
# [[20  0  1]
#  [ 1 21 12]
#  [ 4  5  8]]
# Error Rate: 0.3194444444444444
# Recall Score: 0.6805555555555556
# F1 Score: 0.6835939486397151
# Precision Score: 0.7046906796906797
#
# Performance results for k = 3, test_size = 50.0%, weights = uniform
# Confusion Maxtrix:
# [[26  2  1]
#  [ 4 22 15]
#  [ 5  5  9]]
# Error Rate: 0.3595505617977528
# Recall Score: 0.6404494382022472
# F1 Score: 0.6416478184736611
# Precision Score: 0.6683854541429125
#
# Performance results for k = 4, test_size = 20.0%, weights = uniform
# Confusion Maxtrix:
# [[ 9  1  0]
#  [ 0 11  6]
#  [ 0  5  4]]
# Error Rate: 0.33333333333333337
# Recall Score: 0.6666666666666666
# F1 Score: 0.6739766081871346
# Precision Score: 0.6833333333333333
#
# Performance results for k = 4, test_size = 40.0%, weights = uniform
# Confusion Maxtrix:
# [[18  3  0]
#  [ 1 25  8]
#  [ 3  7  7]]
# Error Rate: 0.3055555555555556
# Recall Score: 0.6944444444444444
# F1 Score: 0.6896746737257985
# Precision Score: 0.6861231361231361
#
# Performance results for k = 4, test_size = 50.0%, weights = uniform
# Confusion Maxtrix:
# [[25  2  2]
#  [ 1 26 14]
#  [ 3  7  9]]
# Error Rate: 0.3258426966292135
# Recall Score: 0.6741573033707865
# F1 Score: 0.6834309983334229
# Precision Score: 0.6999678972712681
#
# Performance results for k = 5, test_size = 20.0%, weights = uniform
# Confusion Maxtrix:
# [[ 9  1  0]
#  [ 0 11  6]
#  [ 0  4  5]]
# Error Rate: 0.3055555555555556
# Recall Score: 0.6944444444444444
# F1 Score: 0.7029727095516569
# Precision Score: 0.7160669191919191
#
# Performance results for k = 5, test_size = 40.0%, weights = uniform
# Confusion Maxtrix:
# [[19  1  1]
#  [ 1 18 15]
#  [ 2  5 10]]
# Error Rate: 0.3472222222222222
# Recall Score: 0.6527777777777778
# F1 Score: 0.6606745077073868
# Precision Score: 0.6968725718725719
#
# Performance results for k = 5, test_size = 50.0%, weights = uniform
# Confusion Maxtrix:
# [[28  0  1]
#  [ 1 20 20]
#  [ 3  5 11]]
# Error Rate: 0.3370786516853933
# Recall Score: 0.6629213483146067
# F1 Score: 0.6704215067362868
# Precision Score: 0.7270365168539327
#
# Performance results for k = 6, test_size = 20.0%, weights = uniform
# Confusion Maxtrix:
# [[10  0  0]
#  [ 1 11  5]
#  [ 0  4  5]]
# Error Rate: 0.2777777777777778
# Recall Score: 0.7222222222222222
# F1 Score: 0.7207819896964635
# Precision Score: 0.7238215488215487
#
# Performance results for k = 6, test_size = 40.0%, weights = uniform
# Confusion Maxtrix:
# [[19  2  0]
#  [ 0 21 13]
#  [ 2  7  8]]
# Error Rate: 0.33333333333333337
# Recall Score: 0.6666666666666666
# F1 Score: 0.6731999269005847
# Precision Score: 0.6843915343915343
#
# Performance results for k = 6, test_size = 50.0%, weights = uniform
# Confusion Maxtrix:
# [[27  0  2]
#  [ 1 23 17]
#  [ 3  7  9]]
# Error Rate: 0.3370786516853933
# Recall Score: 0.6629213483146067
# F1 Score: 0.6734828767007978
# Precision Score: 0.7056015809730924
#
# Performance results for k = 7, test_size = 20.0%, weights = uniform
# Confusion Maxtrix:
# [[10  0  0]
#  [ 1 11  5]
#  [ 0  1  8]]
# Error Rate: 0.19444444444444442
# Recall Score: 0.8055555555555556
# F1 Score: 0.8046059942611667
# Precision Score: 0.8392417767417767
#
# Performance results for k = 7, test_size = 40.0%, weights = uniform
# Confusion Maxtrix:
# [[19  2  0]
#  [ 0 15 19]
#  [ 2  2 13]]
# Error Rate: 0.3472222222222222
# Recall Score: 0.6527777777777778
# F1 Score: 0.6564679330851838
# Precision Score: 0.7326160453216374
#
# Performance results for k = 7, test_size = 50.0%, weights = uniform
# Confusion Maxtrix:
# [[27  0  2]
#  [ 1 17 23]
#  [ 3  2 14]]
# Error Rate: 0.348314606741573
# Recall Score: 0.651685393258427
# F1 Score: 0.6573679452408627
# Precision Score: 0.7726155939658161
#
# Performance results for k = 8, test_size = 20.0%, weights = uniform
# Confusion Maxtrix:
# [[10  0  0]
#  [ 1 11  5]
#  [ 0  4  5]]
# Error Rate: 0.2777777777777778
# Recall Score: 0.7222222222222222
# F1 Score: 0.7207819896964635
# Precision Score: 0.7238215488215487
#
# Performance results for k = 8, test_size = 40.0%, weights = uniform
# Confusion Maxtrix:
# [[21  0  0]
#  [ 1 14 19]
#  [ 3  2 12]]
# Error Rate: 0.3472222222222222
# Recall Score: 0.6527777777777778
# F1 Score: 0.648804347826087
# Precision Score: 0.74959229390681
#
# Performance results for k = 8, test_size = 50.0%, weights = uniform
# Confusion Maxtrix:
# [[26  0  3]
#  [ 1 17 23]
#  [ 3  2 14]]
# Error Rate: 0.3595505617977528
# Recall Score: 0.6404494382022472
# F1 Score: 0.6495461181997081
# Precision Score: 0.7692982456140351
#
# Performance results for k = 9, test_size = 20.0%, weights = uniform
# Confusion Maxtrix:
# [[10  0  0]
#  [ 1 10  6]
#  [ 0  2  7]]
# Error Rate: 0.25
# Recall Score: 0.75
# F1 Score: 0.7493116717254649
# Precision Score: 0.7806591556591557
#
# Performance results for k = 9, test_size = 40.0%, weights = uniform
# Confusion Maxtrix:
# [[20  0  1]
#  [ 1 14 19]
#  [ 2  2 13]]
# Error Rate: 0.3472222222222222
# Recall Score: 0.6527777777777778
# F1 Score: 0.6523737373737373
# Precision Score: 0.7598311008637095
#
# Performance results for k = 9, test_size = 50.0%, weights = uniform
# Confusion Maxtrix:
# [[27  0  2]
#  [ 1 17 23]
#  [ 3  2 14]]
# Error Rate: 0.348314606741573
# Recall Score: 0.651685393258427
# F1 Score: 0.6573679452408627
# Precision Score: 0.7726155939658161
#
# Performance results for k = 10, test_size = 20.0%, weights = uniform
# Confusion Maxtrix:
# [[10  0  0]
#  [ 1 11  5]
#  [ 0  2  7]]
# Error Rate: 0.2222222222222222
# Recall Score: 0.7777777777777778
# F1 Score: 0.7775132275132276
# Precision Score: 0.7979312354312353
#
# Performance results for k = 10, test_size = 40.0%, weights = uniform
# Confusion Maxtrix:
# [[21  0  0]
#  [ 0 14 20]
#  [ 2  2 13]]
# Error Rate: 0.33333333333333337
# Recall Score: 0.6666666666666666
# F1 Score: 0.6656313131313131
# Precision Score: 0.7725122602839993
#
# Performance results for k = 10, test_size = 50.0%, weights = uniform
# Confusion Maxtrix:
# [[28  0  1]
#  [ 1 17 23]
#  [ 3  2 14]]
# Error Rate: 0.3370786516853933
# Recall Score: 0.6629213483146067
# F1 Score: 0.6650518818689751
# Precision Score: 0.7759461856889414

# %%
# Distance Trainer
mass_kNN_trainer(weights='distance')
# Out:
# Performance results for k = 1, test_size = 20.0%, weights = distance
# Confusion Maxtrix:
# [[10  0  0]
#  [ 0 11  6]
#  [ 0  4  5]]
# Error Rate: 0.2777777777777778
# Recall Score: 0.7222222222222222
# F1 Score: 0.7274305555555556
# Precision Score: 0.7377104377104376
#
# Performance results for k = 1, test_size = 40.0%, weights = distance
# Confusion Maxtrix:
# [[18  2  1]
#  [ 0 23 11]
#  [ 2  7  8]]
# Error Rate: 0.3194444444444444
# Recall Score: 0.6805555555555556
# F1 Score: 0.687324242202291
# Precision Score: 0.6963541666666667
#
# Performance results for k = 1, test_size = 50.0%, weights = distance
# Confusion Maxtrix:
# [[27  1  1]
#  [ 1 26 14]
#  [ 2  8  9]]
# Error Rate: 0.3033707865168539
# Recall Score: 0.6966292134831461
# F1 Score: 0.702792054296588
# Precision Score: 0.7155296950240772
#
# Performance results for k = 2, test_size = 20.0%, weights = distance
# Confusion Maxtrix:
# [[10  0  0]
#  [ 0 11  6]
#  [ 0  4  5]]
# Error Rate: 0.2777777777777778
# Recall Score: 0.7222222222222222
# F1 Score: 0.7274305555555556
# Precision Score: 0.7377104377104376
#
# Performance results for k = 2, test_size = 40.0%, weights = distance
# Confusion Maxtrix:
# [[18  2  1]
#  [ 0 23 11]
#  [ 2  7  8]]
# Error Rate: 0.3194444444444444
# Recall Score: 0.6805555555555556
# F1 Score: 0.687324242202291
# Precision Score: 0.6963541666666667
#
# Performance results for k = 2, test_size = 50.0%, weights = distance
# Confusion Maxtrix:
# [[27  1  1]
#  [ 1 26 14]
#  [ 2  8  9]]
# Error Rate: 0.3033707865168539
# Recall Score: 0.6966292134831461
# F1 Score: 0.702792054296588
# Precision Score: 0.7155296950240772
#
# Performance results for k = 3, test_size = 20.0%, weights = distance
# Confusion Maxtrix:
# [[10  0  0]
#  [ 0 10  7]
#  [ 0  4  5]]
# Error Rate: 0.3055555555555556
# Recall Score: 0.6944444444444444
# F1 Score: 0.7014848950332822
# Precision Score: 0.7192460317460317
#
# Performance results for k = 3, test_size = 40.0%, weights = distance
# Confusion Maxtrix:
# [[18  2  1]
#  [ 0 22 12]
#  [ 2  7  8]]
# Error Rate: 0.33333333333333337
# Recall Score: 0.6666666666666666
# F1 Score: 0.6751708853120919
# Precision Score: 0.6875725379757638
#
# Performance results for k = 3, test_size = 50.0%, weights = distance
# Confusion Maxtrix:
# [[25  3  1]
#  [ 1 25 15]
#  [ 2  8  9]]
# Error Rate: 0.3370786516853933
# Recall Score: 0.6629213483146067
# F1 Score: 0.6723000043520446
# Precision Score: 0.6876975209559479
#
# Performance results for k = 4, test_size = 20.0%, weights = distance
# Confusion Maxtrix:
# [[ 9  1  0]
#  [ 0 10  7]
#  [ 0  5  4]]
# Error Rate: 0.36111111111111116
# Recall Score: 0.6388888888888888
# F1 Score: 0.6493531809321283
# Precision Score: 0.6638257575757576
#
# Performance results for k = 4, test_size = 40.0%, weights = distance
# Confusion Maxtrix:
# [[17  3  1]
#  [ 0 20 14]
#  [ 2  6  9]]
# Error Rate: 0.36111111111111116
# Recall Score: 0.6388888888888888
# F1 Score: 0.6513988364089991
# Precision Score: 0.6751770770316596
#
# Performance results for k = 4, test_size = 50.0%, weights = distance
# Confusion Maxtrix:
# [[25  3  1]
#  [ 1 21 19]
#  [ 3  6 10]]
# Error Rate: 0.3707865168539326
# Recall Score: 0.6292134831460674
# F1 Score: 0.640546327725583
# Precision Score: 0.6745318352059926
#
# Performance results for k = 5, test_size = 20.0%, weights = distance
# Confusion Maxtrix:
# [[ 9  1  0]
#  [ 0 11  6]
#  [ 0  4  5]]
# Error Rate: 0.3055555555555556
# Recall Score: 0.6944444444444444
# F1 Score: 0.7029727095516569
# Precision Score: 0.7160669191919191
#
# Performance results for k = 5, test_size = 40.0%, weights = distance
# Confusion Maxtrix:
# [[17  3  1]
#  [ 0 18 16]
#  [ 2  6  9]]
# Error Rate: 0.38888888888888884
# Recall Score: 0.6111111111111112
# F1 Score: 0.6254424005591562
# Precision Score: 0.6575104963262858
#
# Performance results for k = 5, test_size = 50.0%, weights = distance
# Confusion Maxtrix:
# [[27  1  1]
#  [ 1 19 21]
#  [ 3  6 10]]
# Error Rate: 0.3707865168539326
# Recall Score: 0.6292134831460674
# F1 Score: 0.6382551880386568
# Precision Score: 0.6871584604232303
#
# Performance results for k = 6, test_size = 20.0%, weights = distance
# Confusion Maxtrix:
# [[ 9  1  0]
#  [ 0 11  6]
#  [ 0  3  6]]
# Error Rate: 0.2777777777777778
# Recall Score: 0.7222222222222222
# F1 Score: 0.7306678153717627
# Precision Score: 0.749074074074074
#
# Performance results for k = 6, test_size = 40.0%, weights = distance
# Confusion Maxtrix:
# [[17  3  1]
#  [ 0 17 17]
#  [ 2  5 10]]
# Error Rate: 0.38888888888888884
# Recall Score: 0.6111111111111112
# F1 Score: 0.6249829985352585
# Precision Score: 0.6664014202172096
#
# Performance results for k = 6, test_size = 50.0%, weights = distance
# Confusion Maxtrix:
# [[27  0  2]
#  [ 1 19 21]
#  [ 3  5 11]]
# Error Rate: 0.3595505617977528
# Recall Score: 0.6404494382022472
# F1 Score: 0.6511912721579883
# Precision Score: 0.7175669289100199
#
# Performance results for k = 7, test_size = 20.0%, weights = distance
# Confusion Maxtrix:
# [[10  0  0]
#  [ 0 11  6]
#  [ 0  1  8]]
# Error Rate: 0.19444444444444442
# Recall Score: 0.8055555555555556
# F1 Score: 0.8099283691487589
# Precision Score: 0.8535052910052909
#
# Performance results for k = 7, test_size = 40.0%, weights = distance
# Confusion Maxtrix:
# [[18  2  1]
#  [ 0 16 18]
#  [ 2  5 10]]
# Error Rate: 0.38888888888888884
# Recall Score: 0.6111111111111112
# F1 Score: 0.623861778282161
# Precision Score: 0.6724200399800099
#
# Performance results for k = 7, test_size = 50.0%, weights = distance
# Confusion Maxtrix:
# [[27  1  1]
#  [ 1 18 22]
#  [ 3  5 11]]
# Error Rate: 0.3707865168539326
# Recall Score: 0.6292134831460674
# F1 Score: 0.6370166827025
# Precision Score: 0.6983721723557129
#
# Performance results for k = 8, test_size = 20.0%, weights = distance
# Confusion Maxtrix:
# [[10  0  0]
#  [ 0 11  6]
#  [ 0  3  6]]
# Error Rate: 0.25
# Recall Score: 0.75
# F1 Score: 0.7557603686635944
# Precision Score: 0.7738095238095238
#
# Performance results for k = 8, test_size = 40.0%, weights = distance
# Confusion Maxtrix:
# [[18  2  1]
#  [ 0 16 18]
#  [ 2  3 12]]
# Error Rate: 0.36111111111111116
# Recall Score: 0.6388888888888888
# F1 Score: 0.6489005912786401
# Precision Score: 0.7136862092507253
#
# Performance results for k = 8, test_size = 50.0%, weights = distance
# Confusion Maxtrix:
# [[27  0  2]
#  [ 1 18 22]
#  [ 3  3 13]]
# Error Rate: 0.348314606741573
# Recall Score: 0.651685393258427
# F1 Score: 0.6598638222958628
# Precision Score: 0.7536696329737286
#
# Performance results for k = 9, test_size = 20.0%, weights = distance
# Confusion Maxtrix:
# [[10  0  0]
#  [ 0 11  6]
#  [ 0  1  8]]
# Error Rate: 0.19444444444444442
# Recall Score: 0.8055555555555556
# F1 Score: 0.8099283691487589
# Precision Score: 0.8535052910052909
#
# Performance results for k = 9, test_size = 40.0%, weights = distance
# Confusion Maxtrix:
# [[20  0  1]
#  [ 0 14 20]
#  [ 2  3 12]]
# Error Rate: 0.36111111111111116
# Recall Score: 0.6388888888888888
# F1 Score: 0.6439104220499569
# Precision Score: 0.73989898989899
#
# Performance results for k = 9, test_size = 50.0%, weights = distance
# Confusion Maxtrix:
# [[27  0  2]
#  [ 1 17 23]
#  [ 3  3 13]]
# Error Rate: 0.3595505617977528
# Recall Score: 0.6404494382022472
# F1 Score: 0.6474059065512371
# Precision Score: 0.7484052192823487
#
# Performance results for k = 10, test_size = 20.0%, weights = distance
# Confusion Maxtrix:
# [[10  0  0]
#  [ 0 12  5]
#  [ 0  1  8]]
# Error Rate: 0.16666666666666663
# Recall Score: 0.8333333333333334
# F1 Score: 0.8373737373737374
# Precision Score: 0.8675213675213675
#
# Performance results for k = 10, test_size = 40.0%, weights = distance
# Confusion Maxtrix:
# [[19  1  1]
#  [ 0 14 20]
#  [ 2  3 12]]
# Error Rate: 0.375
# Recall Score: 0.625
# F1 Score: 0.6314957264957264
# Precision Score: 0.7170314253647586
#
# Performance results for k = 10, test_size = 50.0%, weights = distance
# Confusion Maxtrix:
# [[27  0  2]
#  [ 1 17 23]
#  [ 3  3 13]]
# Error Rate: 0.3595505617977528
# Recall Score: 0.6404494382022472
# F1 Score: 0.6474059065512371
# Precision Score: 0.7484052192823487

# %%
df.describe()
# Out:
#             Label     Alcohol  Malic Acid         Ash  Alkalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# min     70.000000       0.980000    0.340000              0.130000
# 25%     88.000000       1.742500    1.205000              0.270000
# 50%     98.000000       2.355000    2.135000              0.340000
# 75%    107.000000       2.800000    2.875000              0.437500
# max    162.000000       3.880000    5.080000              0.660000
#
#        Proanthocyanins  Color intensity         Hue  \
# count       178.000000       178.000000  178.000000
# mean          1.590899         5.058090    0.957449
# std           0.572359         2.318286    0.228572
# min           0.410000         1.280000    0.480000
# 25%           1.250000         3.220000    0.782500
# 50%           1.555000         4.690000    0.965000
# 75%           1.950000         6.200000    1.120000
# max           3.580000        13.000000    1.710000
#
#        OD280/OD315 of diluted wines      Proline
# count                    178.000000   178.000000
# mean                       2.611685   746.893258
# std                        0.709990   314.907474
# min                        1.270000   278.000000
# 25%                        1.937500   500.500000
# 50%                        2.780000   673.500000
# 75%                        3.170000   985.000000
# max                        4.000000  1680.000000

# %%
df.data = df[[1,2,6,10,12,13]]
df.data
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-264-7fd0bf5343ef> in <module>()
#       1
# ----> 2 df.data = df[[1,2,6,10,12,13]]
#       3 df.data
#       4
#       5
#
# /home/alexnguyen/anaconda3/envs/data_science_1/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# /home/alexnguyen/anaconda3/envs/data_science_1/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# /home/alexnguyen/anaconda3/envs/data_science_1/lib/python2.7/site-packages/pandas/core/indexing.pyc in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# /home/alexnguyen/anaconda3/envs/data_science_1/lib/python2.7/site-packages/pandas/core/indexing.pyc in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1244                 raise KeyError(
#    1245                     u"None of [{key}] are in the [{axis}]".format(
# -> 1246                         key=key, axis=self.obj._get_axis_name(axis)))
#    1247
#    1248             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: u"None of [Int64Index([1, 2, 6, 10, 12, 13], dtype='int64')] are in the [columns]"
