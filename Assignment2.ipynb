# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn import tree
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
data_location = 'data/wine.csv'
plt.style.use('seaborn')
df = pd.read_csv(filepath_or_buffer=data_location, sep=',', decimal='.', header=None, names=[
    'Label', 'Alcohol', 'Malic Acid', 'Ash', 'Alcalinity of ash', 'Magnesium', 'Total phenols', 'Flavanoids' , 
    'Nonflavanoid phenols', 'Proanthocyanins', 'Color intensity', 'Hue', 'OD280/OD315 of diluted wines', 'Proline']
)
df.head(10)
# Out:
#    Label  Alcohol  Malic Acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
# 5      1    14.20        1.76  2.45               15.2        112
# 6      1    14.39        1.87  2.45               14.6         96
# 7      1    14.06        2.15  2.61               17.6        121
# 8      1    14.83        1.64  2.17               14.0         97
# 9      1    13.86        1.35  2.27               16.0         98
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
# 5           3.27        3.39                  0.34             1.97
# 6           2.50        2.52                  0.30             1.98
# 7           2.60        2.51                  0.31             1.25
# 8           2.80        2.98                  0.29             1.98
# 9           2.98        3.15                  0.22             1.85
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             5.64  1.04                          3.92     1065
# 1             4.38  1.05                          3.40     1050
# 2             5.68  1.03                          3.17     1185
# 3             7.80  0.86                          3.45     1480
# 4             4.32  1.04                          2.93      735
# 5             6.75  1.05                          2.85     1450
# 6             5.25  1.02                          3.58     1290
# 7             5.05  1.06                          3.58     1295
# 8             5.20  1.08                          2.85     1045
# 9             7.22  1.01                          3.55     1045

# %%
# Graph for Labels
val = df['Label'].value_counts()
val.plot(kind='pie', autopct=lambda p: '{:.0f}% ({:.0f})'.format(p, p * sum(val)/100), fontsize=12)
plt.axis("equal")
plt.title('Label Distribution')
plt.xlabel('Frequency')
plt.ylabel('Label')
plt.legend(loc='best')
plt.savefig('single/label.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for alcohol %
sns.boxplot(x='Alcohol', data=df, orient='v', width=0.2)
plt.title('Alcoholic Content Statistics')
plt.legend()
plt.grid()
plt.ylabel('Alcoholic Content')
plt.savefig('single/alcohol.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for alcohol %
sns.kdeplot(data=df['Malic Acid'])
plt.title('Malic Acid Distribution')
plt.legend()
plt.grid()
plt.xlabel('Malic Acid Content')
plt.ylabel('Density Function')
plt.savefig('single/malic_acid.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for alcohol %
sns.boxplot(x='Ash', data=df, orient='v', width=0.2)
plt.title('Ash Content Statistics')
plt.legend()
plt.grid()
plt.ylabel('Ash Content')
plt.savefig('single/ash.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for alcohol %
df['Magnesium'].plot(kind='hist', bins=10, edgecolor="k", facecolor='orange')
plt.title('Magnesium Content Statistics')
plt.legend()
plt.xlabel('Magnesium Content')
plt.ylabel('Frequency')
plt.savefig('single/magnesium.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for Flavanoids %
sns.boxplot(x='Flavanoids', data=df, orient='v', width=0.2)
plt.title('Flavanoids Content Statistics')
plt.legend()
plt.grid()
plt.ylabel('Flavanoids Content')
plt.savefig('single/flavanoids.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for Proline
df['Proline'].plot(kind='hist', bins=10, edgecolor="k", facecolor='teal')
plt.title('Proline Content Distribution')
plt.legend()
plt.xlabel('Proline Content')
plt.savefig('single/proline.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for phenols
sns.distplot(df['Total phenols'], bins=10, color='green')
plt.title('Phenols Distribution')
plt.legend()
plt.grid()
plt.xlabel('Phenols Acid Content')
plt.ylabel('Density Function')
plt.savefig('single/phenols.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for Proanthocyanins
sns.boxplot(x='Proanthocyanins', data=df, orient='v', width=0.2)
plt.title('Proanthocyanins Content Statistics')
plt.legend()
plt.grid()
plt.ylabel('Proanthocyanins Content')
plt.savefig('single/proanthocyanins.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for color intensity %
sns.boxplot(x='Color intensity', data=df, orient='v', width=0.2)
plt.title('Color intensity Statistics')
plt.legend()
plt.grid()
plt.ylabel('Color Intensity')
plt.savefig('single/color_intensity.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
sns.boxplot(x='Label', y='Alcohol', data=df, width=0.3)
plt.suptitle(' ')
plt.ylabel('Alcohol Content')
plt.title('Alcohol Content by Label')
plt.savefig('pair/label_alcohol.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
sns.boxplot(x='Label', y='Malic Acid', data=df, width=0.3)
plt.suptitle(' ')
plt.ylabel('Malic Acid Content')
plt.title('Malic Acid Content by Label')
plt.savefig('pair/label_malic-acid.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
ax = df.groupby('Label')['Ash'].mean().plot.barh(color=['blue', 'orange', 'green'])
ax.set_xlim(0,4)
plt.ylabel('Label')
plt.xlabel('Ash Content')
plt.title('Average Ash Content by Label')
plt.savefig('pair/label_ash.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for hue-color_intensity
sns.lmplot(x = 'Color intensity', y='Hue', data=df)
plt.title('Hue & Color Intensity')
plt.savefig('pair/hue-color_intensity.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for ash-acalinity
sns.lmplot(x = 'Alcalinity of ash', y='Ash', data=df)
plt.title('Ash and its Alcalinity')
plt.savefig('pair/ash_alcalinity.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for hue-Proanthocyanins
sns.lmplot(x = 'Proanthocyanins', y='Hue', data=df)
plt.title('Proanthocyanins and Hue')
plt.savefig('pair/hue_proanthocyanins.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for total phenols-flavanoids
sns.lmplot(x = 'Total phenols', y='Flavanoids', data=df)
plt.title('Total Phenols & Flavanoids')
plt.savefig('pair/flavanoid_phenols.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for total phenols-flavanoids
sns.lmplot(x = 'Color intensity', y='Alcohol', data=df)
plt.title('Alcohol & Color Intensity')
plt.savefig('pair/alcohol_cintensity.png', bbox_inches = 'tight')
plt.show()
plt.close()

# %%
# Graph for label-hue
plt.figure(figsize=(10,6))
sns.violinplot(x='Label', y='Hue', data=df, inner=None)
sns.swarmplot(x='Label', y='Hue', data=df, color='k', alpha=0.5)
plt.title('Hue Distribution by Label')
plt.savefig('pair/label_hue.png', bbox_inches='tight')
plt.show()
plt.close()

# %%
# Classification Tasks
# Decision Tree and k Nearest Neighbors
# Preparing Data Set
data = df.copy()
features = ['Alcohol', 'Malic Acid', 'Ash', 'Alcalinity of ash', 'Magnesium', 'Total phenols', 'Flavanoids' , 
    'Nonflavanoid phenols', 'Proanthocyanins', 'Color intensity', 'Hue', 'OD280/OD315 of diluted wines', 'Proline']
Y = data[['Label']].copy()
X = data[features].copy()

# %%
def train_model_with_decision_tree(max_leaf_nodes, random_state, test_size, x, y):
    X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = test_size, random_state = 20)
    dt = DecisionTreeClassifier(max_leaf_nodes = max_leaf_nodes, random_state = random_state)
    dt = dt.fit(X_train, Y_train)
    # Test
    dt_predictions = dt.predict(X_test)
    print dt_predictions[:15]
    # Confusion Matrix
    print confusion_matrix(y_true = Y_test, y_pred = dt_predictions)
    # Accuracy score
    print 'Accuracy Score: ' + str(accuracy_score(y_true = Y_test, y_pred = dt_predictions))
    # Recall Score
    print 'Recall Score: ' + str(recall_score(y_true = Y_test, y_pred = dt_predictions, average='weighted'))
    # F1 Score
    print 'F1 Score: ' +  str(f1_score(y_true = Y_test, y_pred = dt_predictions, average='weighted'))
    # Precision Score
    print 'Precision Score: ' + str(precision_score(y_true = Y_test, y_pred = dt_predictions, average='weighted'))

# %%
# 50% test size
train_model_with_decision_tree(max_leaf_nodes=15, random_state=20, test_size=0.5, x=X, y=Y)
# Out:
# [2 3 1 2 2 2 3 2 2 3 1 3 2 1 1]
# [[28  1  0]
#  [ 1 40  0]
#  [ 0  0 19]]
# Accuracy Score: 0.9775280898876404
# Recall Score: 0.9775280898876404
# F1 Score: 0.9775280898876404
# Precision Score: 0.9775280898876404

# %%
# 40% test size
train_model_with_decision_tree(max_leaf_nodes=15, random_state=20, test_size=0.4,  x=X, y=Y)
# Out:
# [2 3 1 2 2 2 3 2 2 3 1 3 2 1 1]
# [[20  1  0]
#  [ 1 33  0]
#  [ 0  0 17]]
# Accuracy Score: 0.9722222222222222
# Recall Score: 0.9722222222222222
# F1 Score: 0.9722222222222222
# Precision Score: 0.9722222222222222

# %%
# 20% test size
train_model_with_decision_tree(max_leaf_nodes=15, random_state=20, test_size=0.2,  x=X, y=Y)
# Out:
# [2 3 1 2 3 2 3 2 2 3 1 3 2 2 1]
# [[10  0  0]
#  [ 0 16  1]
#  [ 0  0  9]]
# Accuracy Score: 0.9722222222222222
# Recall Score: 0.9722222222222222
# F1 Score: 0.9725323409533936
# Precision Score: 0.9750000000000001

# %%
def train_model_with_kNN(k_number, test_size, x,y, weights='uniform', random_state=20):
    kN = KNeighborsClassifier(k_number, weights)
    X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = test_size, random_state = random_state)
    kN.fit(X_train, Y_train.values.ravel())
    kN_predictions = kN.predict(X_test)
    print kN_predictions[:15]
    # Confusion Matrix
    print confusion_matrix(y_true = Y_test, y_pred = kN_predictions)
    # Accuracy score
    print 'Accuracy Score: ' + str(accuracy_score(y_true = Y_test, y_pred = kN_predictions))
    # Recall Score
    print 'Recall Score: ' + str(recall_score(y_true = Y_test, y_pred = kN_predictions, average='weighted'))
    # F1 Score
    print 'F1 Score: ' +  str(f1_score(y_true = Y_test, y_pred = kN_predictions, average='weighted'))
    # Precision Score
    print 'Precision Score: ' + str(precision_score(y_true = Y_test, y_pred = kN_predictions, average='weighted'))

# %%
# Uniform, k=3, 50%
train_model_with_kNN(k_number=3, test_size=0.5, x=X, y=Y, weights='uniform', random_state=20)
# Out:
# [2 2 1 3 2 3 3 3 2 3 1 3 3 3 1]
# [[26  2  1]
#  [ 4 22 15]
#  [ 5  5  9]]
# Accuracy Score: 0.6404494382022472
# Recall Score: 0.6404494382022472
# F1 Score: 0.6416478184736611
# Precision Score: 0.6683854541429125

# %%
# Uniform, k=3, 40%
train_model_with_kNN(k_number=3, test_size=0.4, x=X, y=Y, weights='uniform', random_state=20)
# Out:
# [2 2 1 3 2 3 3 3 2 3 1 3 3 3 1]
# [[20  0  1]
#  [ 1 21 12]
#  [ 4  5  8]]
# Accuracy Score: 0.6805555555555556
# Recall Score: 0.6805555555555556
# F1 Score: 0.6835939486397151
# Precision Score: 0.7046906796906797

# %%
# Uniform, k=3 , 20%
train_model_with_kNN(k_number=3, test_size=0.2, x=X, y=Y, weights='uniform', random_state=20)
# Out:
# [2 2 1 3 2 3 3 2 2 3 1 3 3 3 1]
# [[10  0  0]
#  [ 0 10  7]
#  [ 1  3  5]]
# Accuracy Score: 0.6944444444444444
# Recall Score: 0.6944444444444444
# F1 Score: 0.6984126984126984
# Precision Score: 0.7199397824397824

# %%
# Uniform, k=5, 50%
train_model_with_kNN(k_number=5, test_size=0.5, x=X, y=Y, weights='uniform', random_state=20)
# Out:
# [2 2 1 3 2 2 3 3 2 3 1 3 3 3 1]
# [[28  0  1]
#  [ 1 20 20]
#  [ 3  5 11]]
# Accuracy Score: 0.6629213483146067
# Recall Score: 0.6629213483146067
# F1 Score: 0.6704215067362868
# Precision Score: 0.7270365168539327

# %%
# Uniform, k=5, 40%
train_model_with_kNN(k_number=5, test_size=0.4, x=X, y=Y, weights='uniform', random_state=20)
# Out:
# [2 2 1 3 2 2 3 3 2 3 1 3 3 3 1]
# [[19  1  1]
#  [ 1 18 15]
#  [ 2  5 10]]
# Accuracy Score: 0.6527777777777778
# Recall Score: 0.6527777777777778
# F1 Score: 0.6606745077073868
# Precision Score: 0.6968725718725719

# %%
# Uniform, k=5, 20%
train_model_with_kNN(k_number=5, test_size=0.2, x=X, y=Y, weights='uniform', random_state=20)
# Out:
# [2 2 1 3 2 2 3 2 2 3 1 3 3 3 1]
# [[ 9  1  0]
#  [ 0 11  6]
#  [ 0  4  5]]
# Accuracy Score: 0.6944444444444444
# Recall Score: 0.6944444444444444
# F1 Score: 0.7029727095516569
# Precision Score: 0.7160669191919191

# %%
# Uniform, k=7, 50%
train_model_with_kNN(k_number=7, test_size=0.5, x=X, y=Y, weights='uniform', random_state=20)
# Out:
# [2 3 1 3 2 2 3 3 2 3 1 3 3 3 1]
# [[27  0  2]
#  [ 1 17 23]
#  [ 3  2 14]]
# Accuracy Score: 0.651685393258427
# Recall Score: 0.651685393258427
# F1 Score: 0.6573679452408627
# Precision Score: 0.7726155939658161

# %%
# Uniform, k=7, 40%
train_model_with_kNN(k_number=7, test_size=0.4, x=X, y=Y, weights='uniform', random_state=20)
# Out:
# [2 3 1 3 2 2 3 3 2 3 1 3 3 3 1]
# [[19  2  0]
#  [ 0 15 19]
#  [ 2  2 13]]
# Accuracy Score: 0.6527777777777778
# Recall Score: 0.6527777777777778
# F1 Score: 0.6564679330851838
# Precision Score: 0.7326160453216374

# %%
# Uniform, k=7, 20%
train_model_with_kNN(k_number=7, test_size=0.2, x=X, y=Y, weights='uniform', random_state=20)
# Out:
# [2 3 1 3 2 2 3 2 2 3 1 3 3 3 1]
# [[10  0  0]
#  [ 1 11  5]
#  [ 0  1  8]]
# Accuracy Score: 0.8055555555555556
# Recall Score: 0.8055555555555556
# F1 Score: 0.8046059942611667
# Precision Score: 0.8392417767417767

# %%
# distance, k=3, 50%
train_model_with_kNN(k_number=3, test_size=0.5, x=X, y=Y, weights='distance', random_state=20)
# Out:
# [2 2 1 3 2 3 3 3 2 3 1 3 3 3 1]
# [[25  3  1]
#  [ 1 25 15]
#  [ 2  8  9]]
# Accuracy Score: 0.6629213483146067
# Recall Score: 0.6629213483146067
# F1 Score: 0.6723000043520446
# Precision Score: 0.6876975209559479

# %%
# distance, k=3, 40%
train_model_with_kNN(k_number=3, test_size=0.4, x=X, y=Y, weights='distance', random_state=20)
# Out:
# [2 2 1 3 2 3 3 3 2 3 1 3 3 3 1]
# [[18  2  1]
#  [ 0 22 12]
#  [ 2  7  8]]
# Accuracy Score: 0.6666666666666666
# Recall Score: 0.6666666666666666
# F1 Score: 0.6751708853120919
# Precision Score: 0.6875725379757638

# %%
# distance, k=3, 20%
train_model_with_kNN(k_number=3, test_size=0.2, x=X, y=Y, weights='distance', random_state=20)
# Out:
# [2 2 1 3 2 3 3 2 2 3 1 3 3 3 1]
# [[10  0  0]
#  [ 0 10  7]
#  [ 0  4  5]]
# Accuracy Score: 0.6944444444444444
# Recall Score: 0.6944444444444444
# F1 Score: 0.7014848950332822
# Precision Score: 0.7192460317460317

# %%
# distance, k=5, 50%
train_model_with_kNN(k_number=5, test_size=0.5, x=X, y=Y, weights='distance', random_state=20)
# Out:
# [2 2 1 3 2 3 3 3 2 3 1 3 3 3 1]
# [[27  1  1]
#  [ 1 19 21]
#  [ 3  6 10]]
# Accuracy Score: 0.6292134831460674
# Recall Score: 0.6292134831460674
# F1 Score: 0.6382551880386568
# Precision Score: 0.6871584604232303

# %%
# distance, k=5, 40%
train_model_with_kNN(k_number=5, test_size=0.4, x=X, y=Y, weights='distance', random_state=20)
# Out:
# [2 2 1 3 2 3 3 3 2 3 1 3 3 3 1]
# [[17  3  1]
#  [ 0 18 16]
#  [ 2  6  9]]
# Accuracy Score: 0.6111111111111112
# Recall Score: 0.6111111111111112
# F1 Score: 0.6254424005591562
# Precision Score: 0.6575104963262858

# %%
# distance, k=5, 20%
train_model_with_kNN(k_number=5, test_size=0.2, x=X, y=Y, weights='distance', random_state=20)
# Out:
# [2 2 1 3 2 2 3 2 2 3 1 3 3 3 1]
# [[ 9  1  0]
#  [ 0 11  6]
#  [ 0  4  5]]
# Accuracy Score: 0.6944444444444444
# Recall Score: 0.6944444444444444
# F1 Score: 0.7029727095516569
# Precision Score: 0.7160669191919191

# %%
# distance, k=7, 50%
train_model_with_kNN(k_number=7, test_size=0.5, x=X, y=Y, weights='distance', random_state=20)
# Out:
# [2 2 1 3 2 3 3 3 2 3 1 3 3 3 1]
# [[27  1  1]
#  [ 1 18 22]
#  [ 3  5 11]]
# Accuracy Score: 0.6292134831460674
# Recall Score: 0.6292134831460674
# F1 Score: 0.6370166827025
# Precision Score: 0.6983721723557129

# %%
# distance, k=7, 40%
train_model_with_kNN(k_number=7, test_size=0.4, x=X, y=Y, weights='distance', random_state=20)
# Out:
# [2 2 1 3 2 3 3 3 2 3 1 3 3 3 1]
# [[18  2  1]
#  [ 0 16 18]
#  [ 2  5 10]]
# Accuracy Score: 0.6111111111111112
# Recall Score: 0.6111111111111112
# F1 Score: 0.623861778282161
# Precision Score: 0.6724200399800099

# %%
# distance, k=7, 20%
train_model_with_kNN(k_number=7, test_size=0.2, x=X, y=Y, weights='distance', random_state=20)
# Out:
# [2 3 1 3 2 2 3 2 2 3 1 3 3 3 1]
# [[10  0  0]
#  [ 0 11  6]
#  [ 0  1  8]]
# Accuracy Score: 0.8055555555555556
# Recall Score: 0.8055555555555556
# F1 Score: 0.8099283691487589
# Precision Score: 0.8535052910052909

# %%
df.describe()
# Out:
#             Label     Alcohol  Malic Acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# min     70.000000       0.980000    0.340000              0.130000
# 25%     88.000000       1.742500    1.205000              0.270000
# 50%     98.000000       2.355000    2.135000              0.340000
# 75%    107.000000       2.800000    2.875000              0.437500
# max    162.000000       3.880000    5.080000              0.660000
#
#        Proanthocyanins  Color intensity         Hue  \
# count       178.000000       178.000000  178.000000
# mean          1.590899         5.058090    0.957449
# std           0.572359         2.318286    0.228572
# min           0.410000         1.280000    0.480000
# 25%           1.250000         3.220000    0.782500
# 50%           1.555000         4.690000    0.965000
# 75%           1.950000         6.200000    1.120000
# max           3.580000        13.000000    1.710000
#
#        OD280/OD315 of diluted wines      Proline
# count                    178.000000   178.000000
# mean                       2.611685   746.893258
# std                        0.709990   314.907474
# min                        1.270000   278.000000
# 25%                        1.937500   500.500000
# 50%                        2.780000   673.500000
# 75%                        3.170000   985.000000
# max                        4.000000  1680.000000
